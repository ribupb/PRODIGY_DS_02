# %% [markdown]
# #
# <u><h1>Task-02</h1><hr></u>
# <h3>Problem statement -</h3>
# <p>Perform data cleaning and exploratory data analysis (EDA) on a dataset of your choice, such as the Titanic dataset from Kaggle. Explore the relationships between variables and identify patterns and trends in the data.</p>
# <h3>Dataset used - </h3><p>Heart disease</p>
# <h3>Source of the dataset -</h3>
# <p>Kaggle</p>
# <h3>Description -</h3>
# <p>The dataset provided contains essential health attributes crucial for assessing heart disease risk in patients. With features ranging from age and gender to physiological indicators like blood pressure and cholesterol levels, it offers a comprehensive snapshot of individuals cardiovascular health.</p>
# <h3>Aim -</h3>
# <p>The aim of the analysis is to thoroughly clean and explore the dataset, identifying correlations and patterns among various parameters, with a focus on understanding factors associated with heart disease, thereby laying the groundwork for predictive modeling and targeted interventions in cardiovascular health.</p>

# %%
import pandas as pd

heart_disease=pd.read_csv(r"C:\Users\Hp\Downloads\heart.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# # <h2>Data cleaning</h2>
# <p>We will check for missing values and handle them if necessary and ensure that data types are appropriate.</p>

# %%
# Checking for missing values
missing_values = heart_disease.isnull().sum()
print(missing_values)
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
print(heart_disease.dtypes)
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# Removing duplicates
heart_disease.drop_duplicates(inplace=True)

# %%
# Boxplot to identify outliers
plt.figure(figsize=(12, 8))
sns.boxplot(data=heart_disease, orient='h', palette='Set2')
plt.title('Boxplot of Numerical Variables')
plt.show()

# %%
# Displaying cleaned dataset information
print(heart_disease.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 302 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB
# None

# %% [markdown]
# # <h2>Exploratory Data Analysis (EDA)</h2>

# %%
heart_disease.describe(include='all')
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# # <h3>Distribution of the Target Variable</h3>
# <p>Let's visualize the distribution of the target variable which indicates the presence of heart disease.</p>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Target distribution
sns.countplot(x='target', data=heart_disease)
plt.title('Distribution of Heart Disease')
plt.xlabel('Presence of Heart Disease')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # <h3>Numerical Features</h3>
# <p>We will visualize the distribution of key numerical features and their relationship with the target variable.</p>

# %%
# Distribution of Age
sns.histplot(heart_disease['age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.show()

# %%
# Scatter plot of Age vs Maximum Heart Rate Achieved
sns.scatterplot(x='age', y='thalach', hue='target', data=heart_disease)
plt.title('Age vs. Maximum Heart Rate Achieved')
plt.show()

# %%
# Box plot of Resting Blood Pressure by Heart Disease
sns.boxplot(x='target', y='trestbps', data=heart_disease)
plt.title('Resting Blood Pressure by Heart Disease')
plt.xlabel('Presence of Heart Disease')
plt.ylabel('Resting Blood Pressure')
plt.show()

# %%
# Box plot of Serum Cholesterol by Heart Disease
sns.boxplot(x='target', y='chol', data=heart_disease)
plt.title('Serum Cholesterol by Heart Disease')
plt.xlabel('Presence of Heart Disease')
plt.ylabel('Serum Cholesterol')
plt.show()

# %% [markdown]
# # <h3>Categorical Features</h3>
# <p>Now let us examine the impact of some categorical features on the target variable.</p>

# %%
# Heart Disease by Chest Pain Type
sns.countplot(x='cp', hue='target', data=heart_disease)
plt.title('Heart Disease by Chest Pain Type')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.show()

# %%
# Heart Disease by Sex
sns.countplot(x='sex', hue='target', data=heart_disease)
plt.title('Heart Disease by Sex')
plt.xlabel('Sex (0 = female, 1 = male)')
plt.ylabel('Count')
plt.show()

# %%
# Heart Disease by Fasting Blood Sugar
sns.countplot(x='fbs', hue='target', data=heart_disease)
plt.title('Heart Disease by Fasting Blood Sugar')
plt.xlabel('Fasting Blood Sugar > 120 mg/dl')
plt.ylabel('Count')
plt.show()

# %%
# Heart Disease by Resting ECG
sns.countplot(x='restecg', hue='target', data=heart_disease)
plt.title('Heart Disease by Resting ECG')
plt.xlabel('Resting ECG')
plt.ylabel('Count')
plt.show()

# %%
# Heart Disease by Exercise-Induced Angina
sns.countplot(x='exang', hue='target', data=heart_disease)
plt.title('Heart Disease by Exercise-Induced Angina')
plt.xlabel('Exercise-Induced Angina')
plt.ylabel('Count')
plt.show()

# %%
# Heart Disease by Slope of Peak Exercise ST Segment
sns.countplot(x='slope', hue='target', data=heart_disease)
plt.title('Heart Disease by Slope of Peak Exercise ST Segment')
plt.xlabel('Slope of Peak Exercise ST Segment')
plt.ylabel('Count')
plt.show()

# %%
# Heart Disease by Number of Major Vessels
sns.countplot(x='ca', hue='target', data=heart_disease)
plt.title('Heart Disease by Number of Major Vessels')
plt.xlabel('Number of Major Vessels (0-3) colored by fluoroscopy')
plt.ylabel('Count')
plt.show()

# %%
# Heart Disease by Thalassemia
sns.countplot(x='thal', hue='target', data=heart_disease)
plt.title('Heart Disease by Thalassemia')
plt.xlabel('Thalassemia (3 = normal, 6 = fixed defect, 7 = reversible defect)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # <h3>Correlation Analysis</h3>
# <p>Let's look at the correlation between numerical features and the target variable.</p>

# %%
# Correlation matrix
corr_matrix = heart_disease.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# Strongest correlations with Target
corr_target = corr_matrix['target'].sort_values(ascending=False)
print(corr_target.head(10))
print(corr_target.tail(10))
# Out:
# target      1.000000
# cp          0.432080
# thalach     0.419955
# slope       0.343940
# restecg     0.134874
# fbs        -0.026826
# chol       -0.081437
# trestbps   -0.146269
# age        -0.221476
# sex        -0.283609
# Name: target, dtype: float64
# restecg     0.134874
# fbs        -0.026826
# chol       -0.081437
# trestbps   -0.146269
# age        -0.221476
# sex        -0.283609
# thal       -0.343101
# ca         -0.408992
# oldpeak    -0.429146
# exang      -0.435601
# Name: target, dtype: float64

# %% [markdown]
# # <h2>Inference</h2>
# <p>Through data cleaning and exploratory data analysis (EDA) of the Heart Disease dataset, we can find many insights. Firstly, age appears to be a significant factor with the majority of patients falling within the age range of 50s to 60s, and a notable relationship exists between age and maximum heart rate achieved. Additionally, variables such as resting blood pressure, serum cholesterol levels, chest pain type, and fasting blood sugar exhibit evident associations with the presence of heart disease. Furthermore, factors like sex, along with clinical indicators such as resting ECG, exercise-induced angina, and the slope of peak exercise ST segment, all show significant impacts on heart disease diagnosis. The number of major vessels and thalassemia categories also reveal meaningful differences in heart disease prevalence. These insights tells about the various factors in determining heart health, providing valuable groundwork for further predictive modeling and targeted interventions in cardiovascular care.</p>

# %% [markdown]
# # <h2>Conclusion</h2>
# <p>In conclusion, this analysis of the Heart Disease dataset provides valuable insights into factors influencing heart health. Through data cleaning and exploratory analysis, we can identify the significant correlations and patterns among various medical attributes and the presence of heart disease. These findings tells the multifaceted nature of cardiovascular health, emphasizing the importance of considering diverse clinical and demographic factors in diagnosing and managing heart conditions.</p>
